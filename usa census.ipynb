# %% [markdown]
# # United States Census
#
# The data here is for the "Census Income" dataset, which contains data on adults from the 1994 census. This data is labelled with whether the person's yearly income is above or below $50k.

# %% [markdown]
# ### Problem statement
# Here we are looking at the main factors affecting the annual income of a USA citizen.

# %% [markdown]
# ### Data description
#
# The dataset consists of 32,562 rows and 14 features. The description of each feature is given below:
#
#
# Discription about data:
#
# -age: Tells about age of the person and continuous in nature.
#
# -workclass: It defines whether the person belongs to Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked in terms of way of income.
#
# -fnlwgt: It shows financial status and it is continuous in nature.The status of the assets, liabilities, and owners' equity (and their interrelationships) of an organization
#
# -education:It shows education qulalification of person whether they are Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
#
# -education-num:Continuous and represent the education qualification into numbers.
#
# -marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
#
# -occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
#
# -relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
#
# -race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
#
# -sex: Female, Male.
#
# ---Following Dataset attributes shows financial growth of person:
#
# -capital-gain: continuous. Its the rise in the value of a capital asset (investment or real estate) that gives it a higher worth than the purchase price
#
# -capital-loss: continuous. Its the loss incurred when a capital asset, such as an investment or real estate, decreases in value
#
# -hours-per-week: continuous. Its the work hours per week
#
# -native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands

# %%
#importing 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv(r'F:\Documents\ds\usa-income-census.csv') #reading the dataset

# %%
df1
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
df1.info() #getting information about each rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education.num     32561 non-null int64
# marital.status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital.gain      32561 non-null int64
# capital.loss      32561 non-null int64
# hours.per.week    32561 non-null int64
# native.country    32561 non-null object
# income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Data processing
#
# We have to perform the cleaning of the data in order to analysis properly.
#
# We saw that there are ? values in place of some data which are miscoded and doesn't tell anything so we have to replace them with null values and then with most frequent values also

# %%
#replacing the incorrect data with the NaN values
df=df1.replace("?",np.nan)
df
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
#finding the most frequent values
df.mode()
# Out:
#     age workclass  fnlwgt education  education.num      marital.status  \
# 0  36.0   Private  123011   HS-grad            9.0  Married-civ-spouse
# 1   NaN       NaN  164190       NaN            NaN                 NaN
# 2   NaN       NaN  203488       NaN            NaN                 NaN
#
#        occupation relationship   race   sex  capital.gain  capital.loss  \
# 0  Prof-specialty      Husband  White  Male           0.0           0.0
# 1             NaN          NaN    NaN   NaN           NaN           NaN
# 2             NaN          NaN    NaN   NaN           NaN           NaN
#
#    hours.per.week native.country income
# 0            40.0  United-States  <=50K
# 1             NaN            NaN    NaN
# 2             NaN            NaN    NaN

# %%
#checking for the null values
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
#handling null values
df["workclass"]=df["workclass"].fillna("Private")
df["occupation"]=df["occupation"].fillna("Prof-specialty")
df["native.country"]=df["native.country"].fillna("United-States")
df
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
df.isnull().sum()#hence the dataset is cleaned
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %% [markdown]
# ## Univariant analysis

# %%
#for workclass
df["workclass"].describe()
# Out:
# count       32561
# unique          8
# top       Private
# freq        24532
# Name: workclass, dtype: object

# %%
fig = plt.figure(figsize=(10,4))

sns.countplot('workclass', hue='income', data=df)
sns.despine()

# %% [markdown]
# We saw that there a number of person in the private workclass and mostly have income less than 50 k

# %%
#for education
df["education"].describe()
# Out:
# count       32561
# unique         16
# top       HS-grad
# freq        10501
# Name: education, dtype: object

# %%
fig = plt.figure(figsize=(10,6))

chart=sns.countplot('education', hue='income', data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
sns.despine()

# %% [markdown]
# This shows that person having qualification till Bachelors tend to  have less income than the person having higher qualification
# thus education performs a vital role in income of the person

# %%
#for marital status
df["marital.status"].describe()
# Out:
# count                  32561
# unique                     7
# top       Married-civ-spouse
# freq                   14976
# Name: marital.status, dtype: object

# %%
fig = plt.figure(figsize=(10,6))

chart=sns.countplot('marital.status', hue='income', data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
sns.despine()

# %% [markdown]
# Person who is in married to a civilian partner tend to have better chances of high income rahter than others

# %%
#for occupation
df["occupation"].describe()
# Out:
# count              32561
# unique                14
# top       Prof-specialty
# freq                5983
# Name: occupation, dtype: object

# %%
fig = plt.figure(figsize=(10,6))

chart=sns.countplot('occupation', hue='income', data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
sns.despine()

# %% [markdown]
# People of exectutive managerial and professional speciality tend to have high income whereas person involved in other services have low income thus showing that type of occupation also affect the income of the person

# %%
#for relationship
df["relationship"].describe()
# Out:
# count       32561
# unique          6
# top       Husband
# freq        13193
# Name: relationship, dtype: object

# %%
fig = plt.figure(figsize=(10,6))

chart=sns.countplot('relationship', hue='income', data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
sns.despine()

# %% [markdown]
# Majority of the working person are husbands and the unmarried person faces a low income as compared to married ones

# %%
#for race
df["race"].describe()
# Out:
# count     32561
# unique        5
# top       White
# freq      27816
# Name: race, dtype: object

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot('race', hue='income', data=df)
sns.despine()

# %% [markdown]
# Most of the working force are the white ones. There are very few person other than whites that have a high income.

# %%
#for sex
df["sex"].describe()
# Out:
# count     32561
# unique        2
# top        Male
# freq      21790
# Name: sex, dtype: object

# %%
fig = plt.figure(figsize=(10,6))

sns.countplot('sex', hue='income', data=df)

sns.despine()

# %% [markdown]
# There a more males than females in the work force and males occupy most of the section in both above and below of 50k

# %%
#for native country
df["native.country"].describe()
# Out:
# count             32561
# unique               41
# top       United-States
# freq              29753
# Name: native.country, dtype: object

# %%
fig = plt.figure(figsize=(10,6))

chart=sns.countplot('native.country', hue='income', data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
sns.despine()

# %% [markdown]
# Most of the people are native americans.

# %%
gender = {'Male': 1,'Female': 2}
df['sex'] = [gender[item] for item in df['sex']]

# %%
''' we are converting income into integer values where above 50k is assinged as 1 and below 50k as 0'''
def income_to_numeric(x):
    if x=='>50K':
        return 1
    if x=='<=50K':
        return 0
    
df['income1'] = df['income'].apply(income_to_numeric)

# %% [markdown]
# ## correlation among features

# %%
fig = plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), vmin=0, vmax=1,annot=True, linewidth=1)
sns.despine()

# %% [markdown]
# So we see that there is high correlation among these pair
#
# age-income1
#
# education.num-income1
#
# captial.gain-income1
#
# hours.per.week-income1
#
# capital.loss-income1

# %% [markdown]
# ## Bivariant analysis

# %% [markdown]
# So we are going to use above pairs for analysis
#
# ### age-income

# %%
sns.boxplot(y='age',x='income1',hue='income',data=df)
sns.despine()

# %% [markdown]
# This shows that person older age group  have more income than person among younger age group as the younger age group are new to job or have started a startup.
#
#
# ### education.num-income

# %%
sns.boxplot(y='education.num',x='income',data=df)
sns.despine()

# %% [markdown]
# The person with more income tend to have more numbers of educational qualifications
#
#
# ### captial.gain-income

# %%
df['capital.gain1']=df['capital.gain']/10
sns.scatterplot(y='capital.gain1',x='income1',hue='income',data=df,alpha=0.2)
sns.despine()

# %% [markdown]
# ### capital.loss-income1

# %%
sns.scatterplot(y='capital.loss',x='income1',hue='income',data=df,alpha=0.2)
sns.despine()

# %% [markdown]
# Here we see that people having high income tend to have a high capital gain and low capital loss

# %% [markdown]
# ### hours.per.week-income1

# %%
sns.boxplot(y='hours.per.week',x='income',data=df)
sns.despine()

# %% [markdown]
# People having more hours per week tend to have more income whereas person with low income and more hours per week may have started their own startup or business

# %% [markdown]
# ### fnlwgt-income

# %%
df['fnlwgt1']=df['fnlwgt']/100000
sns.boxplot(y='fnlwgt1',x='income',data=df)
sns.despine()

# %% [markdown]
# Both the group of person having high income and low income have almost same financial stauts.

# %%
#pairplot
sns.pairplot(df1,hue="income")
sns.despine()
# Out:
# C:\Users\ankit\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Multi variant analysis

# %%
sns.scatterplot(y='hours.per.week',x='education.num',hue='income',data=df)
sns.despine()

# %% [markdown]
# This shows that person having a number of educational qualification and putting more hours of work in a week have higher income than other

# %%
df['education.num'].describe()
# Out:
# count    32561.000000
# mean        10.080679
# std          2.572720
# min          1.000000
# 25%          9.000000
# 50%         10.000000
# 75%         12.000000
# max         16.000000
# Name: education.num, dtype: float64

# %%
df['age'].describe()
# Out:
# count    32561.000000
# mean        38.581647
# std         13.640433
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
sns.boxplot(y='age',x='education.num',hue='income',data=df)
sns.despine()

# %% [markdown]
# People of middle age tend to have more income and if they have less than average numbers of education qualifications their chances of having more income increases

# %% [markdown]
# ## Conclusion
#
# Thus we get to know that the person who have more number of education qualification and who is putting more hours of work tend to have higher income. Also most of the person are working in the private sector and those who are married have high chances of beign having high income. Most of the executive managers have high income followed by professional specialised ones. Also person in middle age group have high income. Also the person with high capital gain and low capital loss have high income.
#
# thus factors effecting income of a person are:- Age, education qualification and number of qualification, type of workclass, their capital loss and gains, hours of work per week.
